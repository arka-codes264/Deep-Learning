# %%
import numpy as np 
y_predicted = np.array([1,1,0,1,0])
y_true = np.array([0.30,0.7,1,0,0.5])

# %%
def mae(y_true,y_predicted):
    total_error = 0
    for yt,yp in zip(y_true,y_predicted):
        total_error += abs(yt - yp)
    print("Total error:", total_error)

    mae = total_error / len(y_true)
    print("MAE:", mae)
    return mae

# %%
mae(y_true, y_predicted)
# Out:
# Total error: 3.5
# MAE: 0.7
# np.float64(0.7)

# %%
np.mean(np.abs(y_predicted - y_true))
# Out:
# np.float64(0.7)

# %%
eplison = 1e-15

# %%
y_predicted_new = [max(i,eplison) for i in y_predicted]
y_predicted_new
# Out:
# [np.int64(1), np.int64(1), 1e-15, np.int64(1), 1e-15]

# %%
 y_predicted_new = [max(i,1-eplison) for i in y_predicted]
y_predicted_new
# Out:
# [np.int64(1), np.int64(1), 0.999999999999999, np.int64(1), 0.999999999999999]

# %%
y_predicted_new1 = np.array(y_predicted_new)
np.log(y_predicted_new1)
# Out:
# array([ 0.00000000e+00,  0.00000000e+00, -9.99200722e-16,  0.00000000e+00,
#        -9.99200722e-16])

# %%
np.log(y_predicted)
# Out:
# C:\Users\Arka Patra\AppData\Local\Temp\ipykernel_27908\815880036.py:1: RuntimeWarning: divide by zero encountered in log
#   np.log(y_predicted)
# array([  0.,   0., -inf,   0., -inf])

# %%
-np.mean(y_true*np.log(y_predicted_new)+(1-y_true)*np.log(1-y_predicted_new))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 -np.mean(y_true*np.log(y_predicted_new)+(1-y_true)*np.log(1-y_predicted_new))
#
# TypeError: unsupported operand type(s) for -: 'int' and 'list'

# %%
def log_loss(y_true, y_predicted):
    y_predicted_new = [max(i,epsilon) for i in y_predicted]
    y_predicted_new = [min(i,1-epsilon) for i in y_predicted_new]
    y_predicted_new = np.array(y_predicted_new)
    return -np.mean(y_true*np.log(y_predicted_new)+(1-y_true)*np.log(1-y_predicted_new))

# %%
log_loss(y_true, y_predicted)
